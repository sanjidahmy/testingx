# %% [markdown]
# ## Insult generator
#
# write an INSULT generator program
#
# adj adj noun
#
# stupid smelly frog
#
# bald ugly cow
#
# whiney purple refrigerator

# %%
adj1list = ["smelly", "stupid", "idiot", "bushy", "boring",]
adj2list = ["bald", "hairy", "lame", "oily", "fat",]
nounList = ["midget", "elephant", "rat", "snake", "coglione"]

# %%
import random # this is the module that does all random calculations and stuff
# choose one word randomly from the lists
for i in range(100):
    word1=random.choice(adj1list)
    word2=random.choice(adj2list)
    word3=random.choice(nounList)
    print(i," You are a", word1, word2, word3)

#a different method - choose a random integer

x = random.randint (0, len(adj1list)-1)
y = random.randint (0, len(adj2list)-1)
z = random.randint (0, len(nounList)-1)
print(" You are a", adj1list[x], adj2list[y], nounList[z])
# Out:
# 0  You are a smelly hairy coglione
# 1  You are a smelly bald elephant
# 2  You are a bushy fat coglione
# 3  You are a bushy fat midget
# 4  You are a stupid fat rat
# 5  You are a boring bald midget
# 6  You are a boring hairy midget
# 7  You are a smelly fat elephant
# 8  You are a smelly lame elephant
# 9  You are a boring bald coglione
# 10  You are a idiot oily rat
# 11  You are a idiot bald coglione
# 12  You are a stupid bald coglione
# 13  You are a smelly hairy elephant
# 14  You are a boring bald elephant
# 15  You are a idiot oily coglione
# 16  You are a bushy fat midget
# 17  You are a bushy bald rat
# 18  You are a smelly bald elephant
# 19  You are a stupid lame midget
# 20  You are a stupid fat elephant
# 21  You are a stupid oily coglione
# 22  You are a stupid oily rat
# 23  You are a idiot bald elephant
# 24  You are a bushy hairy rat
# 25  You are a idiot lame elephant
# 26  You are a bushy bald elephant
# 27  You are a smelly hairy coglione
# 28  You are a bushy lame coglione
# 29  You are a idiot hairy elephant
# 30  You are a idiot lame midget
# 31  You are a stupid hairy snake
# 32  You are a idiot hairy coglione
# 33  You are a bushy fat elephant
# 34  You are a idiot bald elephant
# 35  You are a boring bald snake
# 36  You are a boring oily midget
# 37  You are a smelly bald elephant
# 38  You are a stupid hairy snake
# 39  You are a stupid bald snake
# 40  You are a smelly bald coglione
# 41  You are a stupid lame snake
# 42  You are a idiot hairy rat
# 43  You are a idiot bald elephant
# 44  You are a bushy oily rat
# 45  You are a idiot lame rat
# 46  You are a stupid lame midget
# 47  You are a bushy oily coglione
# 48  You are a boring oily midget
# 49  You are a bushy hairy midget
# 50  You are a boring lame midget
# 51  You are a smelly lame snake
# 52  You are a boring oily elephant
# 53  You are a bushy lame midget
# 54  You are a smelly oily midget
# 55  You are a bushy fat coglione
# 56  You are a idiot hairy coglione
# 57  You are a smelly bald snake
# 58  You are a smelly oily snake
# 59  You are a idiot lame coglione
# 60  You are a boring hairy midget
# 61  You are a smelly lame elephant
# 62  You are a smelly lame midget
# 63  You are a stupid lame snake
# 64  You are a idiot bald rat
# 65  You are a stupid hairy rat
# 66  You are a bushy oily snake
# 67  You are a bushy bald midget
# 68  You are a bushy oily rat
# 69  You are a smelly oily coglione
# 70  You are a idiot lame midget
# 71  You are a stupid fat snake
# 72  You are a boring hairy elephant
# 73  You are a smelly lame snake
# 74  You are a stupid fat snake
# 75  You are a stupid hairy rat
# 76  You are a boring oily snake
# 77  You are a stupid oily midget
# 78  You are a smelly oily snake
# 79  You are a boring bald rat
# 80  You are a smelly bald snake
# 81  You are a boring lame coglione
# 82  You are a bushy fat rat
# 83  You are a idiot hairy midget
# 84  You are a smelly hairy coglione
# 85  You are a idiot fat coglione
# 86  You are a boring fat coglione
# 87  You are a smelly hairy midget
# 88  You are a smelly fat snake
# 89  You are a bushy bald rat
# 90  You are a idiot lame elephant
# 91  You are a bushy oily rat
# 92  You are a idiot lame midget
# 93  You are a stupid hairy elephant
# 94  You are a idiot bald rat
# 95  You are a bushy fat snake
# 96  You are a stupid bald midget
# 97  You are a boring oily elephant
# 98  You are a boring lame rat
# 99  You are a stupid fat elephant
#  You are a smelly bald rat
